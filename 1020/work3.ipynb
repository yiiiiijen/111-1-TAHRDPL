# %%
#前往爬蟲網站:https://movies.yahoo.com.tw/movie_intheaters.html?guccounter=1&guce_referrer=aHR0cHM6Ly93d3cuZ29vZ2xlLmNvbS8&guce_referrer_sig=AQAAAAdplr5tV-xf-YBfUgeHA9U-4QPWc0lpc66aiXoF2FImz4GiLJoHeVo_TAbCPsnUvib8c5QEpBS0z4eFkXUYPjR-3ku6b4c8ojYN480b2MT9Rt_h2mspwsUfLSxNDzXTJASBdhNepcEO-521Ny3kNsEdSn329mIA7Rjt3mBMF9Sg
#2022現正上映中的電影
import urllib.request as req
import json
import pandas as pd
url = "https://movies.yahoo.com.tw/movie_intheaters.html?guccounter=1&guce_referrer=aHR0cHM6Ly93d3cuZ29vZ2xlLmNvbS8&guce_referrer_sig=AQAAAAdplr5tV-xf-YBfUgeHA9U-4QPWc0lpc66aiXoF2FImz4GiLJoHeVo_TAbCPsnUvib8c5QEpBS0z4eFkXUYPjR-3ku6b4c8ojYN480b2MT9Rt_h2mspwsUfLSxNDzXTJASBdhNepcEO-521Ny3kNsEdSn329mIA7Rjt3mBMF9Sg"

request = req.Request(url, headers = {
    "user-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36"
})

# %%
with req.urlopen(request) as response:
    data = response.read().decode("utf-8")
#print (data) #測試資料輸出
# Out:
# <!DOCTYPE html>
# <html lang="zh_TW">
# <head>
#   <meta charset="UTF-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1, user-minimum-scale=1, maximum-scale=1">
#   <meta http-equiv="content-type" content="text/html; charset=utf-8">
#   <meta property="fb:app_id" content="501887343352051">
#   <meta property="og:site_name" content="Yahoo奇摩電影戲劇">
#   <link rel="icon" href="/favicon.ico?v=2" />
#     <link rel="stylesheet" href="/build/css/pages/movie-list.css?id=284018c850b37cf4aaccefafa2749564&amp;r=1667295665">
#   <link rel="preconnect" href="https://static.xx.fbcdn.net">
#   <link rel="preconnect" href="https://www.facebook.com">
#   <link rel="preload" href="/build/fonts/fontawesome-webfont.woff2?v=4.7.0" as="font" type="font/woff2" crossorigin>
#
#   <title>上映中 - Yahoo奇摩電影戲劇</title>
# <meta name="twitter:title" content="上映中 - Yahoo奇摩電影戲劇">
#   <meta property="og:title" content="上映中 - Yahoo奇摩電影戲劇">
#
# <link rel="canonical" href="https://movies.yahoo.com.tw/movie_intheaters.html?guce_referrer=aHR0cHM6Ly93d3cuZ29vZ2xlLmNvbS8&amp;guce_referrer_sig=AQAAAAdplr5tV-xf-YBfUgeHA9U-4QPWc0lpc66aiXoF2FImz4GiLJoHeVo_TAbCPsnUvib8c5QEpBS0z4eFkXUYPjR-3ku6b4c8ojYN480b2MT9Rt_h2mspwsUfLSxNDzXTJASBdhNepcEO-521Ny3kNsEdSn329mIA7Rjt3mBMF9Sg">
# <meta property="og:url" content="https://movies.yahoo.com.tw/movie_intheaters.html?guce_referrer=aHR0cHM6Ly93d3cuZ29vZ2xlLmNvbS8&amp;guce_referrer_sig=AQAAAAdplr5tV-xf-YBfUgeHA9U-4QPWc0lpc66aiXoF2FImz4GiLJoHeVo_TAbCPsnUvib8c5QEpBS0z4eFkXUYPjR-3ku6b4c8ojYN480b2MT9Rt_h2mspwsUfLSxNDzXTJASBdhNepcEO-521Ny3kNsEdSn329mIA7Rjt3mBMF9Sg">
#
# <meta name="twitter:description" content="Yahoo奇摩電影戲劇提供上映中的最新電影資訊，查詢時刻表、看最新預告片，讓你電影資訊不漏接">
# <meta name="description" content="Yahoo奇摩電影戲劇提供上映中的最新電影資訊，查詢時刻表、看最新預告片，讓你電影資訊不漏接">
#
#   <meta property="og:description" content="Yahoo奇摩電影戲劇提供上映中的最新電影資訊，查詢時刻表、看最新預告片，讓你電影資訊不漏接">
#
# <meta name="twitter:image" content="https://movies.yahoo.com.tw/build/images/ogImage.png?r=1667295665">
# <meta property="og:image" content="https://movies.yahoo.com.tw/build/images/ogImage.png?r=1667295665">
# <meta name="twitter:image:src" content="https://movies.yahoo.com.tw/build/images/ogImage.png?r=1667295665">
# <meta name="keywords" content="電影,院線電影,線上戲劇,線上電影,影劇, yahoo奇摩電影戲劇, 時刻表, 新片, 預告片, 網友滿意榜, yahoo 電影, 劇照, 線上訂票, 票房, 台北票房, 全美票房, 排行榜, 戲院, 片名, 電視, 熱映中, 本週新片, 海報, 滿意度, 期待度">
#
#
#
# <script type="application/ld+json">
#   {
#       "@context": "https://schema.org",
#       "@type": "ItemList",
#       "itemListElement": [{"@type":"ListItem","position":1,"item":{"@type":"Movie","url":"https://movies.yahoo.com.tw/movieinfo_main/%E5%93%A5%E5%85%92%E5%80%91-bros-13337","name":"哥兒們","image":"https://movies.yahoo.com.tw/i/o/production/movies/October2022/3rOMulw4nwLRYlq80nwc-1024x1477.jpg","director":{"@type":"Person","name":"尼可拉斯史托勒"},"dateCreated":"2022-10-28","review":{"@type":"Review","reviewRating":{"@type":"Rating","ratingValue":"4.0"},"author":{"@type":"Person","name":"Ping"},"reviewBody":"幽默流暢不無聊，可以去電影院欣賞"},"aggregateRating":{"@type":"AggregateRating","ratingValue":"4.3","bestRating":"5.0","ratingCount":14}}},{"@type":"ListItem","position":2,"item":{"@type":"Movie","url":"https://movies.yahoo.com.tw/movieinfo_main/%E7%BD%AA%E5%BE%8C%E7%9C%9F%E7%9B%B8-the-post-truth-world-13836","name":"罪後真相","image":"https://movies.yahoo.com.tw/i/o/production/movies/September2022/R4WU6Owkzw14uXP8aAJd-1080x1579.jpg","director":{"@type":"Person","name":"陳奕甫"},"dateCreated":"2022-10-28","review":{"@type":"Review","reviewRating":{"@type":"Rating","ratingValue":"4.0"},"author":{"@type":"Person","name":"MAN"},"reviewBody":"看得還蠻入神..真像大白！如果真相抽象一點的話會更好"},"aggregateRating":{"@type":"AggregateRating","ratingValue":"4.4","bestRating":"5.0","ratingCount":33}}},{"@type":"ListItem","position":3,"item":{"@type":"Movie","url":"https://movies.yahoo.com.tw/movieinfo_main/%E8%AA%BF%E8%81%B7%E4%BB%A4%E6%98%AF%E8%AD%A6%E5%AF%9F%E6%A8%82%E9%9A%8A-offbeat-cops-13881","name":"調職令是警察樂隊！","image":"https://movies.yahoo.com.tw/i/o/production/movies/September2022/zwRTa8Yilz1B25MwYIim-1080x1524.jpg","director":{"@type":"Person","name":"內田英治"},"dateCreated":"2022-10-28","aggregateRating":{"@type":"AggregateRating","ratingValue":"3.6","bestRating":"5.0","ratingCount":4}}},{"@type":"ListItem","position":4,"item":{"@type":"Movie","url":"https://movies.yahoo.com.tw/movieinfo_main/%E5%A4%A7%E4%BF%A0%E8%83%A1%E9%87%91%E9%8A%93-%E7%AC%AC%E4%BA%8C%E9%83%A8%E6%9B%B2-%E6%96%B7%E8%85%B8%E4%BA%BA%E5%9C%A8%E5%A4%A9%E6%B6%AF-the-king-of-wuxia-part-2-the-heartbroken-man-on-the-horizon-13966","name":"大俠胡金銓 第二部曲－斷腸人在天涯","image":"https://movies.yahoo.com.tw/i/o/production/movies/September2022/wqFV1lIV5eiCM5YdXUJy-1080x1600.jpg","director":{"@type":"Person","name":"林靖傑"},"dateCreated":"2022-10-28"}},{"@type":"ListItem","position":5,"item":{"@type":"Movie","url":"https://movies.yahoo.com.tw/movieinfo_main/%E6%B5%81%E9%BA%BB%E6%BA%9D%E5%8D%81%E4%BA%94%E8%99%9F-untold-herstory-14078","name":"流麻溝十五號","image":"https://movies.yahoo.com.tw/i/o/production/movies/September2022/pVpYVY5VKZNmposbiuP2-1080x1600.jpg","director":{"@type":"Person","name":"周美玲"},"dateCreated":"2022-10-28","review":{"@type":"Review","reviewRating":{"@type":"Rating","ratingValue":"5.0"},"author":{"@type":"Person","name":"皮球"},"reviewBody":"音樂很棒，沒有太過搧情仇恨，真實呈現歷史在眼前，真心感受自由民主的可貴"},"aggregateRating":{"@type":"AggregateRating","ratingValue":"4.2","bestRating":"5.0","ratingCount":40}}},{"@type":"ListItem","position":6,"item":{"@type":"Movie","url":"https://movies.yahoo.com.tw/movieinfo_main/%E9%AC%BC%E7%A6%B1-prey-for-the-devil-14119","name":"鬼禱","image":"https://movies.yahoo.com.tw/i/o/production/movies/September2022/cRNL4zu2a19D2sCaJVAl-1080x1544.JPG","director":{"@type":"Person","name":"丹尼爾史坦"},"dateCreated":"2022-10-28","review":{"@type":"Review","reviewRating":{"@type":"Rating","ratingValue":"2.0"},"author":{"@type":"Person","name":"小珊"},"reviewBody":"音效很嚇人，但內容就...隔壁的朋友睡著了"},"aggregateRating":{"@type":"AggregateRating","ratingValue":"4.2","bestRating":"5.0","ratingCount":47}}},{"@type":"ListItem","position":7,"item":{"@type":"Movie","url":"https://movies.yahoo.com.tw/movieinfo_main/%E6%B5%81%E6%B5%AA%E4%B9%8B%E6%9C%88-wandering-14120","name":"流浪之月","image":"https://movies.yahoo.com.tw/i/o/production/movies/October2022/MylTvkYSmNJE7m4lE6RY-500x714.jpg","director":{"@type":"Person","name":"李相日"},"dateCreated":"2022-10-28","review":{"@type":"Review","reviewRating":{"@type":"Rating","ratingValue":"5.0"},"author":{"@type":"Pe ...
#   </script>
#
#   <link rel="stylesheet" href="/build/css/pages/main-layout.css?id=6ef5027c56295df377ac1095bdccaa37&amp;r=1667295665">
#   <meta name="oath:guce:consent-host" content="guce.yahoo.com.tw"/>
#
# <!-- Consent Manager Tag : Script -->
# <script type="text/javascript" src="https://consent.cmp.oath.com/cmp.js" async></script>
#
# <!-- Consent Manager Tag : Stubbed (updated 2018-04-27T17:00) -->
# <script type="text/javascript">
#     (function () {
#         var gdprAppliesGlobally = false;
#
#         function addFrame() {
#             if (!window.frames['__cmpLocator']) {
#                 if (document.body && document.body.firstChild) {
#                     var body = document.body,
#                         iframe = document.createElement('iframe');
#
#                       iframe.style.display = 'none';
# 			  iframe.height = iframe.width = 0;
#
#                     iframe.name = '__cmpLocator';
#                     body.insertBefore(iframe, body.firstChild);
#                 } else {
#                     setTimeout(addFrame, 5);
#                 }
#             }
#         }
#
#         addFrame();
#
#         function stubCMP() {
#             var b = arguments;
#             __cmp.a = __cmp.a || [];
#
#             if (!b.length) return __cmp.a;
#             else if (b[0] === 'ping') {
#                 b[2]({
#                     "gdprAppliesGlobally": gdprAppliesGlobally,
#                     "cmpLoaded": false
#                 }, true);
#             }
#             else {
#                 __cmp.a.push([].slice.apply(b));
#             }
#         }
#
#         function cmpMsgHandler(event) {
#             var msgIsString = typeof event.data === "string";
#             var json = event.data;
#             if (msgIsString) {
#                 try {
#                     json = JSON.parse(event.data);
#                 } catch (e) {}
#             }
#             if (json.__cmpCall) {
#                 var i = json.__cmpCall;
#                 window.__cmp(i.command, i.parameter, function (retValue, success) {
#                     var returnMsg = {
#                         "__cmpReturn": {
#                             "returnValue": retValue,
#                             "success": success,
#                             "callId": i.callId
#                         }
#                     };
#                     event.source.postMessage(msgIsString ?
#                         JSON.stringify(returnMsg) : returnMsg, '*');
#                 });
#             }
#         }
#
#         if (typeof (__cmp) !== 'function') {
#             window.__cmp = stubCMP;
#             __cmp.msgHandler = cmpMsgHandler;
#             if (window.addEventListener)
#                 window.addEventListener('message', cmpMsgHandler, false);
#             else window.attachEvent('onmessage', cmpMsgHandler);
#         }
#     })();
#
# </script>
# <!-- End Consent Manager Tag : Stubbed -->
#
#
# <script type="text/javascript">
#     window.__cmp('init');
# </script>
# <script defer type="text/javascript" src="https://s.yimg.com/nb/AdLib/adlib-prod.umd.min.js"></script>  <script>
#
#     var DARLA_CONFIG = {
#         "positions": {
#             "LREC" : {
#                 id: "LREC",
#                 name: "LREC",
#                 clean: "boxLREC",
#                 dest: "tgtLREC",
#                 w: 300,
#                 h: 250,
#                 //async: true,
#                 metaSize: true
#             },
#             "LREC2" : {
#                 id: "LREC2",
#                 name: "LREC2",
#                 clean: "boxLREC2",
#                 dest: "tgtLREC2",
#                 w: 300,
#                 h: 250,
#                 //async: true,
#                 metaSize: true
#             },
#             "LREC3" : {
#                 id: "LREC3",
#                 name: "LREC3",
#                 clean: "boxLREC3",
#                 dest: "tgtLREC3",
#                 w: 300,
#                 h: 250,
#                 //async: true,
#                 metaSize: true
#             },
#             "LDRB" : {
#                 id: "LDRB",
#                 name: "LDRB",
#                 clean: "boxLDRB",
#                 dest: "tgtLDRB",
#                 w: 728,
#                 h: 90,
#                 //async: true,
#                 metaSize: true
#             },
#             "NP1" : {
#                 id: "NP1",
#                 name: "NP1",
#                 clean: "boxNP1",
#                 dest: "tgtNP1",
#                 w: 300,
#                 h: 100,
#                 async: true,
#                 metaSize: true
#             },
#             //original config
#             // "MAST" : {
#             //     id: "MAST",
#             //     name: "MAST",
#             //     clean: "boxMAST",
#             //     dest: "tgtMAST",
#             //     w: 970,
#             //     h: 250,
#             //     async: true,
#             //     metaSize: true
#             // },
#             //from sports fp
#             "MAST":{
#                 id:"MAST",
#                 name:"MAST", //add
#                 w:970,
#                 h:250,
#                 //async:true, //add
#                 autoFetch:false,
#                 fr:"expIfr_exp",
#                 supports:{
#                     "exp-ovr":1,
#                     "exp-push":1,
#                     "resize-to":1
#                 },
#                 enable:true,
#                 staticLayou:false,
#                 fdb:false,
#                 closeBtn:{
#                     "mode":2,
#                     "useShow":1,
#                     "adc":0
#                 },
#                 metaSize:true,
#                 clean:"boxMAST",
#                 dest:"tgtMAST",
#                 fallback:null,
#                 failed:false
#             },
# 	    	"DEFAULT": {
# 		    	supports: {
# 			    	"bg": 1,
# 				    "exp-ovr": 1,
# 				    "exp-push": 0,
# 				    "lyr": 0,
# 				    "cmsg":1
# 			    }
# 		    }
#         }, events: {
# 		        reloadLREC: {
# 		            ps: 'LREC',
# 		            sp: '794026717'
# 		        },
# 		        reloadNP1: {
# 		            ps: 'NP1',
# 		            sp: '794026717'
# 		        },
# 		        reloadLREC2: {
# 		            ps: 'LREC2',
# 		            sp: '794026717'
# 		        },
# 		        reloadLREC3: {
# 		            ps: 'LREC3',
# 		            sp: '794026717'
# 		        },
# 		    }
#     };
#     // function getCurrentAdsKeys () {
#     //     return Object.keys(window.DARLA_CONFIG.positions).filter(
#     //         function(v) {
#     //             console.log(document.getElementById('box' + v));
#     //             return v !='DEFAULT'
#     //         });
#     // }
#
#     // console.log(getCurrentAdsKeys());
#
#     // DARLA_CONFIG.onFailure = function (e) {
#     //     console.log('DARLA_CONFIG onFailure');
#     // };
#     // DARLA_CONFIG.onTimeout = function (e) {
#     //     console.log('DARLA_CONFIG onTimeout');
#     // };
#     DARLA_CONFIG.onSuccess = function (e, y) {
#         const ads =  Object.keys(DARLA_CONFIG.positions);
#         ads.forEach(ad => {
#             if(!a.includes(ad)) {
#                 const element = document.querySelector(`#box${ad}`);
#                 if(element) {
#                     console.log(`ad ${ad} load failed, set height to 0`);
#                     element.style.height = 0;
#                 }
#             }
#         });
#         // console.log('DARLA_CONFIG onSuccess ');
#         // console.log(y);
#     };
#     // DARLA_CONFIG.onRenderTimeout = function (e) {
#     //     console.log('DARLA_CONFIG onRenderTimeout ');
#     // };
#     // DARLA_CONFIG.onRequestTimeout = function (e) {
#     //     console.log('DARLA_CONFIG onRequestTimeout ');
#     // };
#     // DARLA_CONFIG.onBeforeStartRequest = function (e) {
#     //     console.log('DARLA_CONFIG onBeforeStartRequest');
#     // };
#     // DARLA_CONFIG.onFinishRequest = function (e) {
#     //     console.log('DARLA_CONFIG onFinishRequest');
#     // };
#     // DARLA_CONFIG.onStartParse = function (e) {
#     //     console.log('DARLA_CONFIG onStartParse');
#     // };
#     // DARLA_CONFIG.onPreParse = function (e) {
#     //     console.log('DARLA_CONFIG onPreParse');
#     // };
#     // DARLA_CONFIG.onStartPosRender = function (e) {
#     //     console.log('DARLA_CONFIG onStartPosRender ');
#     //     console.log(e);
#     // };
#     // DARLA_CONFIG.onFinishPosRender = function (posId, reqList, posItem) {
#     //     console.log('DARLA_CONFIG onFinishPosRender');
#     //     console.log(posId);
#     //     console.log(reqList);
#     //     console.log(posItem);
#     // };
#     // DARLA_CONFIG.onBeforePosMsg = function (e) {
#     //     console.log('DARLA_CONFIG onBeforePosMsg');
#     // };
#     // DARLA_CONFIG.onFinishParse = function (e) {
#     //     console.log('DARLA_CONFIG onFinishParse');
#     // };
#     // DARLA_CONFIG.onStartPrefetchRequest = function (e) {
#     //     console.log('DARLA_CONFIG onStartPrefetchRequest');
#     // };
#     // DARLA_CONFIG.onFinishPrefetchRequest = function (e) {
#     //     console.log('DARLA_CONFIG onFinishPrefetchRequest');
#     // };
#  </script>
#  <script src="https://fc.yahoo.com/sdarla/php/client.php?f=794026717&debug=1&l=MAST{dest:tgtMAST,azn:970x250},LREC{dest:tgtLREC,azn:300x250},LREC2{dest:tgtLREC2,azn:300x250},LREC3{dest:tgtLREC3,azn:300x250},NP1{dest:tgtNP1,azn:300x100},LDRB{dest:tgtLDRB,azn:728x90}&amp;npv=1&amp;"></script>
#
# </head>
#
# <body id="">
#      <div id="movie-list"></div>
#     <data data-login="false" data-login-href="https://movies.yahoo.com.tw/login"></data>
#   <span id="tracking-data"
#      data-spaceid="794026717"      data-pt="utility"          data-pstcat="上映中"               ></span>
#   <!--Website-->
#   <div id="maincontainer">
#     <header class="header">
#       <div id="y-header">
#     <nav class="nav content">
#         <ul>
#             <li><a class="gabtn" href="https://tw.yahoo.com/" data-ga="['頻道入口','頻道入口_Yahoo首頁','頁首_頻道入口']"><span class="icon_home"></span>首頁</a></li>
#             <li><a class="gabtn" href="https://tw.mail.yahoo.com/" data-ga="['頻道入口','頻道入口_信箱','頁首_頻道入口']">信箱</a></li>
#             <li><a class="gabtn" href="https://tw.news.yahoo.com/" data-ga="['頻道入口','頻道入口_新聞','頁首_頻道入口']">新聞</a></li>
#             <li><a class="gabtn" href="https://tw.stock.yahoo.com/" data-ga="['頻道入口','頻道入口_股市','頁首_頻道入口']">股市</a></li>
#             <li><a class="gabtn" href="https://tw.news.yahoo.com/weather-forecast/" data-ga="['頻道入口','頻道入口_氣象','頁首_頻道入口']">氣象</a></li>
#             <li><a class="gabtn" href="https://tw.sports.yahoo.com/" data-ga="['頻道入口','頻道入口_運動','頁首_頻道入口']">運動</a></li>
#             <li><a class="gabtn" href="https://tw.news.yahoo.com/entertainment" data-ga="['頻道入口','頻道入口_名人娛樂','頁首_頻道入口']">名人娛樂</a></li>
#             <li><a class="gabtn" href="http://tw.mobile.yahoo.com/" data-ga="['頻道入口','頻道入口_App下載','頁首_頻道入口']">App下載</a></li>
#             <li><a class="gabtn" href="https://tw.buy.yahoo.com/" data-ga="['頻道入口','頻道入口_購物中心','頁首_頻道入口']">購物中心</a></li>
#             <li><a class="gabtn" href="https://tw.mall.yahoo.com/" data-ga="['頻道入口','頻道入口_商域','頁首_頻道入口']">商城</a></li>
#             <li><a class="gabtn" href="https://tw.bid.yahoo.com/" data-ga="['頻道入口','頻道入口_拍賣','頁首_頻道入口']">拍賣</a></li>
#             <li class="nav_more">
#                 <a href="javascript:void(0)">更多<span class="icon_more"></span></a>
#                 <div class="dropdown_list">
#                     <dl>
#                         <dd><a class="gabtn" href="https://tw.video.yahoo.com/" data-ga="['頻道入口','頻道入口_影音','頁首_頻道入口']">影音</a></dd>
#                         <dd><a class="gabtn" href="https://autos.yahoo.com.tw/" data-ga="['頻道入口','頻道入口_汽車機車','頁首_頻道入口']">汽車機車</a></dd>
#                         <dd><a class="gabtn" href="https://movies.yahoo.com.tw/" data-ga="['頻道入口','頻道入口_電影','頁首_頻道入口']">電影</a></dd>
#                         <dd><a class="gabtn" href="https://tw.dictionary.yahoo.com/" data-ga="['頻道入口','頻道入口_字典','頁首_頻道入口']">字典</a></dd>
#                         <dd><a class="gabtn" href="https://games.yahoo.com.tw/" data-ga="['頻道入口','頻道入口_遊戲','頁首_頻道入口']">遊戲</a></dd>
#                         <dd><a class="gabtn" href="https://travel.yahoo.com.tw/" data-ga="['頻道入口','頻道入口_旅遊','頁首_頻道入口']">旅遊</a></dd>
#                         <dd><a class="gabtn" href="https://tw.money.yahoo.com/" data-ga="['頻道入口','頻道入口_理財','頁首_頻道入口']">理財</a></dd>
#                         <dd><a class="gabtn" href="https://house.yahoo.com.tw/" data-ga="['頻道入口','頻道入口_房地產','頁首_頻道入口']">房地產</a></dd>
#                         <dd><a class="gabtn" href="https://style.yahoo.com.tw/" data-ga="['頻道入口','頻道入口_時尚美妝','頁首_頻道入口']">時尚美妝</a></dd>
#                         <dd><a class="gabtn" href="https://tw.discount.yahoo.net/index.php?group=all" data-ga="['頻道入口','頻道入口_折扣城','頁首_頻道入口']">折扣城</a></dd>
#                     </dl>
#                 </div>
#             </li>
#         </ul>
#     </nav>
# </div>
# <div id="kv">
#     <div class="content">
#         <div id="y_hous_serch" class="_c">
#             <div id="y_serch_l">
#                 <a id="ylogo" class="gabtn" href="https://movies.yahoo.com.tw/index.html" data-ga="['電影頻道logo','電影頻道logo_連結','頁首_電影頻道logo']">
#                     <img src="/build/images/header_logo.png?r=1667295665" srcset="/build/images/header_logo@2x.png?r=1667295665 2x, /build/images/header_logo@3x.png?r=1667295665 3x" alt="Yahoo Logo" />
#                 </a>
#                 <form method="get" action="https://tw.search.yahoo.com/search" target="_blank">
#                     <input id="serchinput" name="p" type="text" placeholder="搜尋"  autocomplete="off">
#                     <div class="inputex" style="visibility:hidden"></div>
#
#                     <button class="serch_movie gabtn" data-ga="['top search','top search_電影明星搜尋','']" data-input="['input','serchinput','']">影劇、明星搜尋</button><!--20170531-->
#                     <button class="gabtn" type="submit" data-ga="['top search','top search_網頁搜尋','']" data-input="['input','serchinput','']">網頁搜尋</button><!--20170531-->
#                     <input type="hidden" id="fr" name="fr" value="ush-movies">
#                 </form>
#             </div>
#
#         </div>
#     </div>
# </div>
# <!-- jurisdiction-type: WORLD -->
# <div id="bg_main_menu">
#   <div class="content">
#     <ul id="mainmenu">
#                         <li class="">
#             <a href="https://movies.yahoo.com.tw" target="" class="gabtn" data-ga="['選單','選單_首頁','頁首_選單']">
#               <span>首頁</span>
#             </a>
#           </li>
#                                 <li class="">
#             <a href="https://movies.yahoo.com.tw/movie_thisweek.html" target="" class="gabtn" data-ga="['選單','選單_本週新片','頁首_選單']">
#               <span>本週新片</span>
#             </a>
#           </li>
#                                 <li class=" select ">
#             <a href="https://movies.yahoo.com.tw/movie_intheaters.html" target="" class="gabtn" data-ga="['選單','選單_上映中','頁首_選單']">
#               <span>上映中</span>
#             </a>
#           </li>
#                                 <li class="">
#             <a href="https://movies.yahoo.com.tw/movie_comingsoon.html" target="" class="gabtn" data-ga="['選單','選單_即將上映','頁首_選單']">
#               <span>即將上映</span>
#             </a>
#           </li>
#                                 <li class="">
#             <a href="https://movies.yahoo.com.tw/trailer_index.html" target="" class="gabtn" data-ga="['選單','選單_預告片','頁首_選單']">
#               <span>預告片</span>
#             </a>
#           </li>
#                                 <li class="">
#             <a href="https://movies.yahoo.com.tw/chart.html" target="" class="gabtn" data-ga="['選單','選單_排行榜','頁首_選單']">
#               <span>排行榜</span>
#             </a>
#           </li>
#                                 <li class="hassub ">
#             <a href="https://movies.yahoo.com.tw/article_index.html" class="gabtn" target="" data-ga="['選單','選單_情報站','頁首_選單']">
#               <span>情報站</span>
#             </a>
#             <div class="submenu">
#               <dl class="submenu_inner">
#                                   <dt>
#                       <a href="https://movies.yahoo.com.tw/tagged/movieheadline" target="" class="gabtn" data-ga="['選單','選單_情報站_電影新聞','頁首_選單']">
#                         電影新聞
#                       </a>
#                   </dt>
#                                   <dt>
#                       <a href="https://movies.yahoo.com.tw/tagged/spotlight" target="" class="gabtn" data-ga="['選單','選單_情報站_專題報導','頁首_選單']">
#                         專題報導
#                       </a>
#                   </dt>
#                                   <dt>
#                       <a href="https://movies.yahoo.com.tw/tagged/moviereview" target="" class="gabtn" data-ga="['選單','選單_情報站_影評','頁首_選單']">
#                         影評
#                       </a>
#                   </dt>
#                               </dl>
#             </div>
#           </li>
#                                 <li class="">
#             <a href="https://movies.yahoo.com.tw/tv_index.html" target="" class="gabtn" data-ga="['選單','選單_電視時刻','頁首_選單']">
#               <span>電視時刻</span>
#             </a>
#           </li>
#                                 <li class="hassub ">
#             <a href="https://movies.yahoo.com.tw/ott_index.html" class="gabtn" target="" data-ga="['選單','選單_追劇','頁首_選單']">
#               <span>追劇</span>
#             </a>
#             <div class="submenu">
#               <dl class="submenu_inner">
#                                   <dt>
#                       <a href="https://movies.yahoo.com.tw/tagged/ottdrama" target="" class="gabtn" data-ga="['選單','選單_追劇_追劇情報','頁首_選單']">
#                         追劇情報
#                       </a>
#                   </dt>
#                                   <dt>
#                       <a href="https://movies.yahoo.com.tw/tagged/ottmovie" target="" class="gabtn" data-ga="['選單','選單_追劇_線上電影情報','頁首_選單']">
#                         線上電影情報
#                       </a>
#                   </dt>
#                                   <dt>
#                       <a href="https://movies.yahoo.com.tw/ott_drama.html" target="" class="gabtn" data-ga="['選單','選單_追劇_熱門線上影劇','頁首_選單']">
#                         熱門線上影劇
#                       </a>
#                   </dt>
#                                   <dt>
#                       <a href="https://movies.yahoo.com.tw/category.html" target="" class="gabtn" data-ga="['選單','選單_追劇_影劇檢索','頁首_選單']">
#                         影劇檢索
#                       </a>
#                   </dt>
#                                   <dt>
#                       <a href="https://movies.yahoo.com.tw/tagged/drama-ranking" target="" class="gabtn" data-ga="['選單','選單_追劇_戲劇排行榜','頁首_選單']">
#                         戲劇排行榜
#                       </a>
#                   </dt>
#                               </dl>
#             </div>
#           </li>
#                                 <li class="">
#             <a href="https://movies.yahoo.com.tw/tagged/2022goldenhousefest" target="" class="gabtn" data-ga="['選單','選單_金馬影展','頁首_選單']">
#               <span>金馬影展</span>
#             </a>
#           </li>
#                   </ul>
#   </div>
# </div>
#     </header>
#     <!--主內容-->
#     <main>
#       <!--top_ad-->
#       <div class="maincontent ">
#                   <div id="boxMAST" class="boxAD">
#             <div id="tgtMAST" class="adpos"></div>
#           </div>
#                 <div id="top_serch" class="content _c">
#           <div data-topserch="0">
#     <div class="tab_serch _c">
#         <div class="tab_hot">
#                             <a href="https://movies.yahoo.com.tw/movieinfo_main/哥兒們-bros-13337" target=""
#                    class="gabtn" data-ga="['search box','search box_熱門1','哥兒們']">哥兒們</a>
#                             <a href="https://movies.yahoo.com.tw/movieinfo_main/罪後真相-the-post-truth-world-13836" target=""
#                    class="gabtn" data-ga="['search box','search box_熱門2','張孝全']">張孝全</a>
#                             <a href="https://movies.yahoo.com.tw/yahoo-weekly-drama-115746856.html" target=""
#                    class="gabtn" data-ga="['search box','search box_熱門3','追劇報報']">追劇報報</a>
#                     </div>
#         <a class="btn_booking btn_toptxt gabtn" target="_blank"
#            data-ga="['search box','search box_訂票客服中心','']"
#            href="https://www.ezding.com.tw/page/faq/faq.html">訂票客服中心</a>
#         <a class="btn_all btn_toptxt gabtn" href="https://movies.yahoo.com.tw/theater_list.html"
#            data-ga="['search box','search box_戲院總覽','']">戲院總覽</a>
#         <div class="btn_index_search">
#             <i class="fa fa-file-text-o" aria-hidden="true"></i>
#             <a class="btn_toptxt gabtn" href="https://movies.yahoo.com.tw/category.html"
#            data-ga="['search box','search box_戲院總覽','']">影劇檢索</a>
#         </div>
#     </div>
#
#     <span id="mainURL" data-url="https://movies.yahoo.com.tw"></span>
#     <span id="searchType" data-type="0"></span>
#     <div class="tab_serchbar">
#         <div class="icon_serch"></div>
#         <select name="search_type" id="movie_time">
#             <option value="0">電影時刻</option>
#             <option value="1">電視時刻</option>
#             <option value="2">快速訂票</option>
#             <option value="3">電影/影劇/明星搜尋</option>
#         </select>
#
#         <!--tab_serchbar  style0-->
#         <div class="top_change" data-change = "0" style="">
#             <form id="form_moviearea" method="get" action="https://movies.yahoo.com.tw/movietime_result.html">
#                 <span>選擇<br>片名</span>
#                     <select id="sbox_mid" name="movie_id" class="movie_name" data-loaded="false" data-url="https://movies.yahoo.com.tw/ajax/in_theater_movies">
#                         <option value="">請選擇片名</option>
#                     </select>
#                 <span>選擇<br>地區</span>
#                 <select id="sbox_aid" name="area_id" class="movie_area">
#
#                 </select>
#                 <div class="btn_serch gabtn"
#                      data-ga="['search box','search box_電影時刻','']" data-input="['select','sbox_mid','sbox_aid']">查詢</div>
#             </form>
#         </div>
#
#         <!--tab_serchbar  style1-->
#         <div class="top_change" data-change = "1" style="display:none;">
#             <form id="form_catechannel" method="get" action="https://movies.yahoo.com.tw/tv_channels.html" style="display:inline;">
#                 <span>選擇<br>分類</span>
#                 <select id="sbox_cid" name="tv_category_id" class="movie_theater">
#                     <option value="">請選擇分類</option>
#                                                                         <option value="1" data-name="西片">西片</option>
#                                                     <option value="2" data-name="國片">國片</option>
#                                                     <option value="3" data-name="戲劇">戲劇</option>
#                                                     <option value="4" data-name="體育">體育</option>
#                                                     <option value="5" data-name="綜合">綜合</option>
#                                                     <option value="6" data-name="知性">知性</option>
#                                                     <option value="7" data-name="日本">日本</option>
#                                                     <option value="8" data-name="音樂">音樂</option>
#                                                     <option value="9" data-name="卡通">卡通</option>
#                                                     <option value="10" data-name="新聞">新聞</option>
#                                                     <option value="11" data-name="財經">財經</option>
#                                                     <option value="12" data-name="宗教">宗教</option>
#                                                             </select>
#                 <span>選擇<br>頻道</span>
#                 <select id="sbox_chid" name="channel" class="movie_name">
#                 </select>
#                 <div class="btn_serch gabtn"
#                      data-ga="['search box','search box_電視時刻','']" data-input="['select','sbox_cid','sbox_chid']">查詢</div>
#             </form>
#             <form id="form_channelname" method="get" action="https://movies.yahoo.com.tw/tvtime_result.html" style="display:inline;">
#                 <input id="sbox_cname" class="tvserch" id="tv_channel_name" name="tv_channel_name" type="text" placeholder="電視節目查詢"  autocomplete="off"
#                        onfocus="this.placeholder=''" onblur="this.placeholder='電視節目查詢'" onkeypress="chlSearchForm(event);">
#                 <div class="btn_serch gabtn" data-ga="['search box','search box_電視節目查詢','']" data-input="['input','sbox_cname','']">查詢</div>
#             </form>
#         </div>
#
#         <!--tab_serchbar  style2-->
#         <div class="top_change" data-change = "2" style="display:none;">
#             <form id="form_movieticket" method="get" action="https://www.ezding.com.tw/page/booking/index.html?channel=yahoo&campaign_code=yahoopc">
#                 <span>選擇<br>戲院</span>
#                 <select id="sbox_tid" name="cinemaId" class="movie_theater" data-loaded="false" data-url="https://movies.yahoo.com.tw/ajax/cinemas">
#                     <option value="">請選擇戲院</option>
#                 </select>
#                 <span>選擇<br>片名</span>
#                 <select id="sbox_tmid" name="movieId" class="movie_name">
#
#                 </select>
#                 <span>選擇<br>日期</span>
#                 <select name="showDate" class="movie_day">
#
#                 </select>
#                 <span>選擇<br>場次</span>
#                 <select name="session" class="movie_screenings">
#
#                 </select>
#                 <span>選擇<br>數量</span>
#                 <select name="ticketQuantity" class="movie_amount">
#
#                 </select>
#                 <div class="btn_serch gabtn" data-ga="['search box','search box_快速訂票','']"
#                      data-input="['select','sbox_tid','sbox_tmid']">查詢</div>
#             </form>
#         </div>
#
#         <!--tab_serchbar  style3-->
#         <div class="top_change" data-change = "3" style="display:none;">
#             <form id="form_starsearch" method="get" action="https://movies.yahoo.com.tw/moviesearch_result.html">
#                 <select name="movie_type">
#                     <option value="all">全部</option>
#                     <option value="movie">院線電影</option>
#                     <option value="drama">戲劇影集</option>
#                     <option value="online_movie">線上電影</option>
#                 </select>
#                 <input id="starserch" class="starserch" type="text" name="keyword" placeholder="電影 / 明星搜尋"
#                        onfocus="this.placeholder=''" onblur="this.placeholder='電影/ 明星搜尋'" autocomplete="off">
#                 <div class="inputex" style="visibility:hidden">
#                 </div>
#                 <div class="btn_serch gabtn" data-ga="['search box','search box_電影明星搜尋','']"
#                      data-input="['input','starserch','']">查詢</div>
#             </form>
#         </div>
#
#     </div>
# </div>
#         </div>
#                 <div id="container" class="content _c">
#           <div id="content_r">
#             <!--AD 300X250-->
# <div id="boxLREC" class="ad_300_250 r_box" data-ad="LREC" data-ad-hashtag="">
#   <div id="tgtLREC" class="adpos"></div>
# </div>
# <!--AD 300X100-->
# <div id="boxNP1" class="ad_300_100 r_box" data-ad="NP1">
#   <div id="tgtNP1" class="adpos"></div>
# </div>
# <!--電影排行榜-->
# <div class="r_box _c">
#   <div class="title">
#         <span>
#             電影排行榜
#         </span>
#   </div>
#
#   <div class="r_box_inner">
#     <ul class="tabbox_btn_r">
#       <li data-id="list1" class="select">台北票房榜</li>
#       <li data-id="list2" data-loaded="false" data-url="https://movies.yahoo.com.tw/ajax/movie_rank_tab" data-type="us">全美票房榜</li>
#       <li data-id="list3" data-loaded="false" data-url="https://movies.yahoo.com.tw/ajax/movie_rank_tab" data-type="popular">預告片榜</li>
#     </ul>
#     <div class="ranking_inner_r">
#       <div class="tab-content">
#         <div id="list1" class="tab-pane">
#           <div class="ranking_top_info_r _c">
#             <div class="ranking_top_info_img_r">
#             <a
#                 class="gabtn"
#                 href="https://movies.yahoo.com.tw/movieinfo_main/%E9%BB%91%E4%BA%9E%E7%95%B6-black-adam-13462"
#                 data-ga="['電影排行榜','電影排行榜_台北票房榜','黑亞當']"
#             >
#                 <img src="https://movies.yahoo.com.tw/i/r/w420/production/movies/September2022/F90ayjIO6pdW6sxSMW2X-1080x1560.jpg" alt="">
#             </a>
#         </div>
#         <div class="ranking_top_info_inner_r">
#             <a
#                 class="gabtn"
#                 href="https://movies.yahoo.com.tw/movieinfo_main/%E9%BB%91%E4%BA%9E%E7%95%B6-black-adam-13462"
#                 data-ga="['電影排行榜','電影排行榜_台北票房榜','黑亞當']"
#             >
#                 黑亞當
#             </a>
#             <span class="text_truncate_4 text_truncate_dot">在遠古的坎達克，特斯亞當（巨石強森　飾演）被賦予眾神的強大力量，但因他將力量用在復仇，於是被囚禁，後成為黑亞當。經過近5000年後，黑亞當從人類成為神話，再成為傳奇；如今他已獲得釋放，但其獨特的正義形式是出於憤怒，因此受到當今正義協會的英雄們挑戰，包含鷹俠、命運博士、原子粉碎者和旋風。<br />
# <br />
# 《黑亞當》由豪梅寇勒特瑟拉執導，劇本由亞當希特克、羅里海恩斯及索赫拉布諾希爾瓦尼撰寫，故事及角色改編自DC漫畫。黑亞當一角由比爾帕克及C.C.貝克所創作。製片包含比尤弗林、巨石強森、丹妮賈西亞、海勒姆賈西亞，以及理查德布雷納、濱田沃特、戴夫諾伊斯塔特、克里斯潘恩、艾瑞克麥克勞德、傑夫強斯和斯科特謝爾登。</span>
#         </div>
#     </div>
#
# <ul class="ranking_list_r">
#                                         <a
#                     class="gabtn"
#                     href="https://movies.yahoo.com.tw/movieinfo_main/%E9%BB%91%E4%BA%9E%E7%95%B6-black-adam-13462"
#                     data-ga="['電影排行榜','電影排行榜_台北票房榜','黑亞當']"
#                 >
#                     <li class="select">
#                         <div class="num">1</div>
#                         <span>黑亞當</span>
#                     </li>
#                 </a>
#                                                 <a
#                     class="gabtn"
#                     href="https://movies.yahoo.com.tw/movieinfo_main/%E6%B5%81%E9%BA%BB%E6%BA%9D%E5%8D%81%E4%BA%94%E8%99%9F-untold-herstory-14078"
#                     data-ga="['電影排行榜','電影排行榜_台北票房榜','流麻溝十五號']"
#                 >
#                     <li class="">
#                         <div class="num">2</div>
#                         <span>流麻溝十五號</span>
#                     </li>
#                 </a>
#                                                 <a
#                     class="gabtn"
#                     href="https://movies.yahoo.com.tw/movieinfo_main/%E7%BD%AA%E5%BE%8C%E7%9C%9F%E7%9B%B8-the-post-truth-world-13836"
#                     data-ga="['電影排行榜','電影排行榜_台北票房榜','罪後真相']"
#                 >
#                     <li class="">
#                         <div class="num">3</div>
#                         <span>罪後真相</span>
#                     </li>
#                 </a>
#                                                 <a
#                     class="gabtn"
#                     href="https://movies.yahoo.com.tw/movieinfo_main/%E9%AC%BC%E7%A6%B1-prey-for-the-devil-14119"
#                     data-ga="['電影排行榜','電影排行榜_台北票房榜','鬼禱']"
#                 >
#                     <li class="">
#                         <div class="num">4</div>
#                         <span>鬼禱</span>
#                     </li>
#                 </a>
#                                                 <a
#                     class="gabtn"
#                     href="https://movies.yahoo.com.tw/movieinfo_main/%E4%BD%A0%E5%9C%A8%E6%88%91%E5%BF%83%E4%B8%8A-you-are-on-my-mind-14031"
#                     data-ga="['電影排行榜','電影排行榜_台北票房榜','你在我心上']"
#                 >
#                     <li class="">
#                         <div class="num">5</div>
#                         <span>你在我心上</span>
#                     </li>
#                 </a>
#                                                 <a
#                     class="gabtn"
#                     href="https://movies.yahoo.com.tw/movieinfo_main/%E5%93%A5%E5%85%92%E5%80%91-bros-13337"
#                     data-ga="['電影排行榜','電影排行榜_台北票房榜','哥兒們']"
#                 >
#                     <li class="">
#                         <div class="num">6</div>
#                         <span>哥兒們</span>
#                     </li>
#                 </a>
#                                                 <a
#                     class="gabtn"
#                     href="https://movies.yahoo.com.tw/movieinfo_main/%E5%B9%B8%E7%A6%8F%E5%85%A5%E5%A0%B4%E5%88%B8-ticket-to-paradise-13611"
#                     data-ga="['電影排行榜','電影排行榜_台北票房榜','幸福入場券']"
#                 >
#                     <li class="">
#                         <div class="num">7</div>
#                         <span>幸福入場券</span>
#                     </li>
#                 </a>
#                                                 <li class=" unclick">
#                     <div class="num">8</div>
#                     <span>全明星星光音樂會</span>
#                 </li>
#                                                 <a
#                     class="gabtn"
#                     href="https://movies.yahoo.com.tw/movieinfo_main/%E7%8A%AC%E7%8E%8B-inu-oh-14073"
#                     data-ga="['電影排行榜','電影排行榜_台北票房榜','犬王']"
#                 >
#                     <li class="">
#                         <div class="num">9</div>
#                         <span>犬王</span>
#                     </li>
#                 </a>
#                                                 <a
#                     class="gabtn"
#                     href="https://movies.yahoo.com.tw/movieinfo_main/%E5%BE%AE%E7%AC%91-smile-13558"
#                     data-ga="['電影排行榜','電影排行榜_台北票房榜','微笑']"
#                 >
#                     <li class="">
#                         <div class="num">10</div>
#                         <span>微笑</span>
#                     </li>
#                 </a>
#                         </ul>
#
# <div class="rankin_time_r">統計時間 : 2022-10-29~2022-10-30</div>
#         </div>
#         <div id="list2" class="tab-pane"></div>
#         <div id="list3" class="tab-pane"></div>
#       </div>
#       <div class="btn_plus_more gabtn rk"  data-ga="['電影排行榜','電影排行榜_台北票房榜_看更多','']">
#         <a href="https://movies.yahoo.com.tw/chart.html">
#           <div class="plus"></div>看更多
#         </a>
#       </div>
#       <div class="btn_plus_more gabtn rk" data-ga="['電影排行榜','電影排行榜_全美票房榜_看更多','']">
#         <a href="https://movies.yahoo.com.tw/chart.html?cate=us">
#           <div class="plus"></div>看更多
#         </a>
#       </div>
#       <div class="btn_plus_more gabtn rk" data-ga="['電影排行榜','電影排行榜_預告片榜_看更多','']">
#         <a href="https://movies.yahoo.com.tw/chart.html?cate=trailer">
#           <div class="plus"></div>看更多
#         </a>
#       </div>
#     </div>
#   </div>
# </div>
# <!--AD 300X156-->
# <div class="native-ad-right">
# </div>
# <!--AD 300X250-->
# <div id="boxLREC3" class="ad_300_250 r_box" data-ad="LREC3">
#   <div id="tgtLREC3" class="adpos"></div>
# </div>
#
# <!--FB-->
# <div class="fb r_box">
#
#   <div class="fb-page fb-position-fixed" data-href="https://www.facebook.com/Ymovie/" data-tabs="timeline" data-width="300" data-height="500" data-small-header="false" data-adapt-container-width="true" data-hide-cover="false" data-show-facepile="false" data-lazy="true"><blockquote cite="https://www.facebook.com/Ymovie/" class="fb-xfbml-parse-ignore"><a href="https://www.facebook.com/Ymovie/">Yahoo奇摩電影戲劇</a></blockquote></div>
# </div>
# <!--AD 300X250-->
# <div id="boxLREC2" class="ad_300_250 r_box" data-ad="LREC2">
#   <div id="tgtLREC2" class="adpos"></div>
# </div>
# <!--你最近瀏覽的電影-->
# <div class="r_box _c">
#   <div class="title">
#         <span>
#             你最近瀏覽的電影
#         </span>
#   </div>
#   <div class="r_box_inner">
#           <ul class="recently_viewed">
#               </ul>
#       </div>
# </div>
#
# <div></div>
#           </div>
#           <div id="content_l">
#               <div class="title ">
#     <h1>
#         上映中
#     </h1>
#   </div>
#
#     <div class="release_box">
#     <ul class="filter-nav">
#                         <li><a href="https://movies.yahoo.com.tw/movie_intheaters.html" class="picked">院線電影</a></li>
#                                 <li><a href="https://movies.yahoo.com.tw/drama_intheaters.html">戲劇影集</a></li>
#                                 <li><a href="https://movies.yahoo.com.tw/onlinemovie_intheaters.html">線上電影</a></li>
#             </ul>
#         <ul class="release_list">
#                       <li>
#           <div class="release_foto">
#             <a href="https://movies.yahoo.com.tw/movieinfo_main/%E5%93%A5%E5%85%92%E5%80%91-bros-13337"
#                class="gabtn" data-ga="['上映中','上映中_上映中第1頁','哥兒們']">
#                <div class="type_label movie">院線電影</div>
#               <img class="lazy-load" data-src="https://movies.yahoo.com.tw/i/r/w420/production/movies/October2022/3rOMulw4nwLRYlq80nwc-1024x1477.jpg" alt="">
#             </a>
#           </div>
#           <div class="release_info">
#             <div class="release_info_text">
#               <div class="release_movie_name">
#                 <a href="https://movies.yahoo.com.tw/movieinfo_main/%E5%93%A5%E5%85%92%E5%80%91-bros-13337"
#                    class="gabtn" data-ga="['上映中','上映中_上映中第1頁','哥兒們']">
#                   哥兒們</a>
#                 <div class="en">
#                   <a href="https://movies.yahoo.com.tw/movieinfo_main/%E5%93%A5%E5%85%92%E5%80%91-bros-13337"
#                      class="gabtn" data-ga="['上映中','上映中_上映中第1頁','哥兒們']">
#                     Bros</a>
#                 </div>
#                 <dl class="levelbox">
#                                     <dt>
#                   <div class="level_name">期待度</div>
#                   <div class="leveltext">
#                     <span>71%</span>
#                     網友想看
#                   </div>
#                   </dt>
#                                                       <dd>
#                     <div class="level_name">滿意度</div>
#                     <div class="leveltext">
#                       <span class="count" data-run="0" data-num="4.3">0</span>
#                       綜合評分
#                     </div>
#                   </dd>
#                                   </dl>
#               </div>
#
#               <div class="release_drama_season">
#                               </div>
#               <div class="release_movie_time">
#                 <span>上映日期：</span>
#                 2022-10-28
#               </div>
#               <div class="release_text">
#                 <span class="jq_text_overflow_180 jq_text_overflow_href_list" data-url="https://movies.yahoo.com.tw/movieinfo_main/%E5%93%A5%E5%85%92%E5%80%91-bros-13337">
#                   今年秋天，環球影業將驕傲地推出首部好萊塢主要電影公司製作，關於兩名男同志，也許、可能、大概將會墜入愛河的愛情喜劇片。也許吧。不管怎樣，他們都會非常忙碌。<br />
# <br />
# 喜劇天才比利埃西納（《比利街頭秀》、2019年《獅子王》、《難處之人》、《美國犯罪故事：彈劾》）、傑出的賣座電影導演尼可拉斯史托勒（《惡鄰纏身》系列、《忘掉負心女》）以及金牌喜劇導演/製片賈德阿帕托（《史泰登島國王》、《姐姐愛最大》、《愛情昏迷中》）共同打造出《哥兒們》一片，這是一部在這個瘋狂世界關於性、愛情及浪漫情懷，極具巧思、心醉神迷和暖心動人的喜劇片。<br />
# <br />
# 《哥兒們》一片由比利埃西納領銜主演，他是第一位公開出櫃，共同編寫並主演一部好萊塢大製作電影的男同志。這部電影的導演是尼可拉斯史托勒，他和比利埃西納則是共同編劇；製片包括賈德阿帕托、尼可拉斯史托勒及喬許丘奇（《姐姐愛最大》、《爛兄爛弟》共同製片）；執行製片是比利埃西納。
#                 </span>
#               </div>
#
#
#             </div>
#             <div class="release_btn color_btnbox">
#               <a href="https://movies.yahoo.com.tw/movieinfo_main/%E5%93%A5%E5%85%92%E5%80%91-bros-13337" class="btn_s_introduction"
#                  class="gabtn" data-ga="['上映中','上映中_上映中第1頁','哥兒們']">
#                                      <span>電影資訊</span>
#                               </a>
#                                             <a href="https://movies.yahoo.com.tw/video/%E5%93%A5%E5%85%92%E5%80%91-%E9%99%90%E5%88%B6%E7%B4%9A%E9%A0%90%E5%91%8A-025514988.html?movie_id=13337"
#                    class="btn_s_vedio gabtn" data-ga="['上映中','上映中_上映中第1頁','哥兒們']">
#                   預告片
#                 </a>
#                                             <a href="https://movies.yahoo.com.tw/movieinfo_photos.html/id=13337" class="btn_s_foto">劇照</a>
#                                                               <a href="https://movies.yahoo.com.tw/movietime_result.html/id=13337"
#                     class="btn_s_time gabtn" data-ga="['上映中','上映中_上映中第1頁','哥兒們']">
#                     時刻表
#                   </a>
#                                           </div>
#           </div>
#         </li>
#                       <li>
#           <div class="release_foto">
#             <a href="https://movies.yahoo.com.tw/movieinfo_main/%E7%BD%AA%E5%BE%8C%E7%9C%9F%E7%9B%B8-the-post-truth-world-13836"
#                class="gabtn" data-ga="['上映中','上映中_上映中第1頁','罪後真相']">
#                <div class="type_label movie">院線電影</div>
#               <img class="lazy-load" data-src="https://movies.yahoo.com.tw/i/r/w420/production/movies/September2022/R4WU6Owkzw14uXP8aAJd-1080x1579.jpg" alt="">
#             </a>
#           </div>
#           <div class="release_info">
#             <div class="release_info_text">
#               <div class="release_movie_name">
#                 <a href="https://movies.yahoo.com.tw/movieinfo_main/%E7%BD%AA%E5%BE%8C%E7%9C%9F%E7%9B%B8-the-post-truth-world-13836"
#                    class="gabtn" data-ga="['上映中','上映中_上映中第1頁','罪後真相']">
#                   罪後真相</a>
#                 <div class="en">
#                   <a href="https://movies.yahoo.com.tw/movieinfo_main/%E7%BD%AA%E5%BE%8C%E7%9C%9F%E7%9B%B8-the-post-truth-world-13836"
#                      class="gabtn" data-ga="['上映中','上映中_上映中第1頁','罪後真相']">
#                     The Post-Truth World</a>
#                 </div>
#                 <dl class="levelbox">
#                                     <dt>
#                   <div class="level_name">期待度</div>
#                   <div class="leveltext">
#                     <span>86%</span>
#                     網友想看
#                   </div>
#                   </dt>
#                                                       <dd>
#                     <div class="level_name">滿意度</div>
#                     <div class="leveltext">
#                       <span class="count" data-run="0" data-num="4.4">0</span>
#                       綜合評分
#                     </div>
#                   </dd>
#                                   </dl>
#               </div>
#
#               <div class="release_drama_season">
#                               </div>
#               <div class="release_movie_time">
#                 <span>上映日期：</span>
#                 2022-10-28
#               </div>
#               <div class="release_text">
#                 <span class="jq_text_overflow_180 jq_text_overflow_href_list" data-url="https://movies.yahoo.com.tw/movieinfo_main/%E7%BD%AA%E5%BE%8C%E7%9C%9F%E7%9B%B8-the-post-truth-world-13836">
# ...
#                   <a href="https://movies.yahoo.com.tw/movieinfo_main/%E9%80%83%E5%87%BA%E9%A2%A8%E6%9A%B4-and-tomorrow-we-will-be-dead-14155"
#                      class="gabtn" data-ga="['上映中','上映中_上映中第1頁','逃出風暴']">
#                     And Tomorrow We Will Be Dead</a>
#                 </div>
#                 <dl class="levelbox">
#                                     <dt>
#                   <div class="level_name">期待度</div>
#                   <div class="leveltext">
#                     <span>100%</span>
#                     網友想看
#                   </div>
#                   </dt>
#                                                     </dl>
#               </div>
#
#               <div class="release_drama_season">
#                               </div>
#               <div class="release_movie_time">
#                 <span>上映日期：</span>
#                 2022-10-28
#               </div>
#               <div class="release_text">
#                 <span class="jq_text_overflow_180 jq_text_overflow_href_list" data-url="https://movies.yahoo.com.tw/movieinfo_main/%E9%80%83%E5%87%BA%E9%A2%A8%E6%9A%B4-and-tomorrow-we-will-be-dead-14155">
#                   ★瑞士電影獎Swiss Film Prize最佳演員、最佳音樂、 最佳攝影獎等三項大獎提名 <br />
# ★柏林影展首映、蘇黎士影展開幕片<br />
# ★改編自真人真事同名暢銷書 緊張刺激 熱血沸騰<br />
# ★瑞士旅客大衛和魏德默被塔利班擺上交換西迪基談判桌<br />
# ★瑞士影史賣座第三名《Rascals on the Road》最佳瑞士電影獎導演 邁克爾史坦納執導<br />
# ★瑞士角逐奧斯卡外語片代表《禁愛風暴》男主角史凡雪克主演<br />
# ★旅遊真實事件，我們明天都將會死。緊張刺激、熱血沸騰    <br />
# ★逃出風暴！逃出柬浦寨？人質肉票跨國救援，漫天叫價，絕對扣人心弦<br />
# ★令人興奮，沒有一秒鐘喘息機會<br />
# <br />
# 本片改編自真實事件，瑞士情侶2011年7月在巴基斯坦被塔利班綁架囚禁八個月<br />
# 驚心動魄跨國救援<br />
# 〈劇情〉一對情侶自駕小巴沿著穿越亞洲絲綢之路上旅行，旅途中在巴基斯坦突被聖戰士綁架並關押，塔利班只想以他們交換大筆贖金和作為跨國人質交換的籌碼，他們經歷了令人毛骨悚然的軟禁生活，在這過程中受盡煎熬，兩人最後究竟是否能成功逃脫塔利班指揮官的囚禁與掌控…？<br />
# <br />
# 【關於電影】<br />
# <br />
# 電影《逃出風暴》（And Tomorrow We Will Be Dead）改編自兩名瑞士公民大衛（Olivier David Och）和丹妮拉魏德默（Daniela Widmer）真人真事，根據書籍《明天你就死定了：被塔利班扣為人質 259 天》（Und morgen seid ihr tot: 259 Tage als Geiseln der Taliban）改編而成，此片在蘇黎世電影節的開幕式上全球首映，瑞士導演邁克爾史坦納 (Michael Steiner) 贏得超多觀眾支持與肯定，這部電影徹底震撼了瑞士和外國影迷們，並為導演贏得了瑞士電影獎四項提名。<br />
# <br />
# 劇情講述一對瑞士情侶丹妮拉（Daniela Widmer） 和大衛（David Och）親身遭遇的悲慘綁架故事，他們在 2011 年追隨馬可波羅的腳步踏上一場絲路之旅，途中不幸在巴基斯坦被綁架並被脅持為人質，被一群塔利班戰士綁架八個月。<br />
# <br />
# 這是一個震驚瑞士公眾輿論的故事，至今仍是瑞士民眾津津樂道討論的話題之一，因為他們是迄今為止唯一成功逃脫綁架者的人質。這部電影由女主角摩根費魯（Morgane Ferru）和2015 瑞士角逐奧斯卡外語片代表《禁愛風暴》男主角史凡雪克（Sven Schelker）主演，在印度拉賈斯坦邦、瑞士蘇黎世和阿爾高之間以及西班牙南部的內華達山脈地區拍攝。<br />
# <br />
# 導演邁克爾史坦納的目標，就是從述丹妮拉和大衛的角度，講述這個令人難以置信、可怕的故事，探索他們面臨關押時所感受到的情感和恐懼，揭開他們逃跑的爭議和真相：如果是為了隱瞞官方所不承認的贖金？真的有可能逃脫一個不尊重人命的武裝團體嗎？<br />
# <br />
# 瑞士導演試圖恢復其合理性和尊嚴。這對瑞士情侶所踏上的旅程，忠實呈現他們所遭遇的危險，而且毫無疑問，他們的天真和不願意命運妥協的信念發揮了很大的作用，他們的經歷是真實而令人毛骨悚然的。而這些真實的事實和強烈的情緒，對影片的兩位主角構成巨大挑戰，整體表演令人信服，絕不浮誇！<br />
# <br />
# 電影故事主軸探討了複雜和意想不到的人際關係，例如兩名人質與扣押他們的塔利班組織指揮官納薩強Nazarjan（Siddhant Karnick 飾演）之間展開的關係，以及探討女性的地位和傑出的表演，這是一部引人入勝且結構合理的作品。儘管我們希望丹妮拉和大衛最終能過獲得釋放，擺脫這個可怕的惡夢以及不可磨滅的可怕記憶。<br />
# 此片受到許多瑞士媒體的肯定與讚賞，瑞士公共廣播組織SRF Kultur 電台報導：「導演邁克爾史坦納 (Michael Steiner) 和編劇烏爾斯•布勒 (Urs Bühler) 合作製作了一部令人興奮的、樸實無華的、最好的經典電影劇。」<br />
# <br />
# 《新蘇黎世報》給這部電影 4 星（滿分 5 星）並盛讚：「一個引人入勝的故事，以扣人心弦的畫面，講述他們的真實命運和他們堅定的意志。」<br />
#  <br />
# 在線電影平台 Cineman 寫道：「這部電影是重要和勇敢的，因為它關注個人命運，在塔利班在阿富汗重新掌權的時候，這一點更加重要。」<br />
# <br />
# 瑞士媒體公司CH Media寫道：「導演邁克爾史坦納的故事片以兩名人質為視角，講述了惡劣的條件、他們的恐懼，即使是劫持人質的人也面臨的危險。這些都是他在描述瑞士試圖釋放人質時表現出弱點」<br />
# <br />
# 《新蘇黎世報》寫道：「經過長時間的籌備工作，電影中產生的東西可以自信地被描述為偉大的電影。 攝影師費力普祖姆布倫(Filip Zumbrunn) 的攝影機拍攝出驚人的場面調度，Adrian Frutiger 的配樂也沒過於搶戲，以及主要演員女主角摩根費魯(Morgane Ferru) 和男主角瑞凡雪克 (Sven Schelker) 的精采表演。」<br />
# <br />
# 瑞士電影和遊戲平台 Outnow 評價 5 顆星（滿分 6 顆星）：「邁克爾史坦納的新電影一直佔據著大銀幕。導演近距離講述了丹妮拉威德默和大衛奧赫的經歷。無論他們喜歡與否，它都吸引著觀眾前進戲院觀賞。這部電影很大程度上是非政治性的，講述的主軸是人民。」
#                 </span>
#               </div>
#
#
#             </div>
#             <div class="release_btn color_btnbox">
#               <a href="https://movies.yahoo.com.tw/movieinfo_main/%E9%80%83%E5%87%BA%E9%A2%A8%E6%9A%B4-and-tomorrow-we-will-be-dead-14155" class="btn_s_introduction"
#                  class="gabtn" data-ga="['上映中','上映中_上映中第1頁','逃出風暴']">
#                                      <span>電影資訊</span>
#                               </a>
#                                             <a href="https://movies.yahoo.com.tw/video/%E9%80%83%E5%87%BA%E9%A2%A8%E6%9A%B4-%E4%B8%AD%E6%96%87%E9%A0%90%E5%91%8A-160443813.html?movie_id=14155"
#                    class="btn_s_vedio gabtn" data-ga="['上映中','上映中_上映中第1頁','逃出風暴']">
#                   預告片
#                 </a>
#                                             <a href="https://movies.yahoo.com.tw/movieinfo_photos.html/id=14155" class="btn_s_foto">劇照</a>
#                                                               <a href="https://movies.yahoo.com.tw/movietime_result.html/id=14155"
#                     class="btn_s_time gabtn" data-ga="['上映中','上映中_上映中第1頁','逃出風暴']">
#                     時刻表
#                   </a>
#                                           </div>
#           </div>
#         </li>
#                       <li>
#           <div class="release_foto">
#             <a href="https://movies.yahoo.com.tw/movieinfo_main/%E7%AC%91%E5%AD%90%E7%95%B6%E8%80%81%E5%A4%A7-hometown-14171"
#                class="gabtn" data-ga="['上映中','上映中_上映中第1頁','笑子當老大']">
#                <div class="type_label movie">院線電影</div>
#               <img class="lazy-load" data-src="https://movies.yahoo.com.tw/i/r/w420/production/movies/October2022/sQ3xoO9BfHeBv5ZQdEOP-1024x1463.jpg" alt="">
#             </a>
#           </div>
#           <div class="release_info">
#             <div class="release_info_text">
#               <div class="release_movie_name">
#                 <a href="https://movies.yahoo.com.tw/movieinfo_main/%E7%AC%91%E5%AD%90%E7%95%B6%E8%80%81%E5%A4%A7-hometown-14171"
#                    class="gabtn" data-ga="['上映中','上映中_上映中第1頁','笑子當老大']">
#                   笑子當老大</a>
#                 <div class="en">
#                   <a href="https://movies.yahoo.com.tw/movieinfo_main/%E7%AC%91%E5%AD%90%E7%95%B6%E8%80%81%E5%A4%A7-hometown-14171"
#                      class="gabtn" data-ga="['上映中','上映中_上映中第1頁','笑子當老大']">
#                     Hometown</a>
#                 </div>
#                 <dl class="levelbox">
#                                     <dt>
#                   <div class="level_name">期待度</div>
#                   <div class="leveltext">
#                     <span>98%</span>
#                     網友想看
#                   </div>
#                   </dt>
#                                                       <dd>
#                     <div class="level_name">滿意度</div>
#                     <div class="leveltext">
#                       <span class="count" data-run="0" data-num="2.7">0</span>
#                       綜合評分
#                     </div>
#                   </dd>
#                                   </dl>
#               </div>
#
#               <div class="release_drama_season">
#                               </div>
#               <div class="release_movie_time">
#                 <span>上映日期：</span>
#                 2022-10-28
#               </div>
#               <div class="release_text">
#                 <span class="jq_text_overflow_180 jq_text_overflow_href_list" data-url="https://movies.yahoo.com.tw/movieinfo_main/%E7%AC%91%E5%AD%90%E7%95%B6%E8%80%81%E5%A4%A7-hometown-14171">
#                   ★ 爆笑、親情、浪漫、意想不到的感動一應俱全！<br />
# ★《熱戀年代》導演打造南韓黑幫動作喜劇新紀元！<br />
# ★晴天霹靂！失去所有的無名諧星，竟然返鄉變身黑道老大！<br />
# ★錯綜複雜的人生際遇！無法預測的刺激奇想！將讓觀眾驚喜連連！<br />
# ★「性格男星」宋詩曦搞笑演出，重返故鄉為20億勾起「繼承的決心」！<br />
# ★《政客誠實中》青龍獎影后羅美蘭，守護故鄉家人，展現另類魅力！<br />
# ★南韓「元祖喜劇之王」與「喜劇女王」共創200%爆笑化學反應！<br />
# ★榮登南韓本土新片票房冠軍，觀眾大讚：笑淚交織！感動無比！<br />
# ★貼近生活的幽默與溫暖感動！與親朋好友共同觀賞樂趣加倍！<br />
# <br />
# 善小被人欺，歸鄉大逆襲<br />
# 夢想當偕星而離家出走的基世（宋詩曦飾演），隨著所屬脫口秀突然停播，讓他一夕之間失去所有。此時，他的黑幫老大父親也意外過世，讓他決定重返故鄉，並在那裡與初戀女友永心（羅美蘭飾演）重逢。這時，叔叔康敦（李凡秀飾演）提議他繼承父親的幫派，以及20億高額遺產。這項誘人的提議，讓基世肖想靠這筆錢再度逆轉人生。不過計畫趕不上變化，他捲入無法預測的事件當中，逼他開始面對父親的死亡真相…。基世將順利接掌父親的幫派，並繼承20億遺產嗎？而他與永心的戀情，又將會往什麼樣的方向發展呢？<br />
# <br />
# 【關於電影】<br />
# <br />
# 爆笑、親情、感動、動作一應俱全，黑幫動作喜劇新紀元！<br />
# 《笑子當老大》由擅長貼近生活的幽默，以及刻劃魅力十足的角色，因此備受觀眾喜愛的李延宇導演執導，也是他繼李鍾碩、朴寶英主演《熱戀年代》之後，睽違八年的最新編導作品。本片刻畫失去一切的無名偕星，時隔十五年重返故鄉，意外繼承黑幫組織所發生的故事。「無名偕星當黑幫老大」的異想天開情節，透過瘋狂喜劇融合犯罪驚悚題材，將展現無法預測的多重魅力，勢必將為觀眾帶來溫暖的安慰與歡樂的笑聲。<br />
# <br />
# 由宋詩曦、羅美蘭、李凡秀等充滿個性的喜劇王牌演員領軍，「喜劇之王」與「喜劇女王」的相遇，勢必將為本片展現多彩多姿的魅力。首先，透過電影《極速快遞》、《真犯》、《七年之夜》、《危險的見面禮》和電視劇《我的大叔》，以完美演技穿梭在所有體裁作品的宋詩曦，在片中詮釋心酸爆發的無名諧星「基世」，將以一聽難忘的特有口條消化角色，不僅將演繹角色的傻氣，更透過精湛內心戲引發觀眾共鳴。此外，曾演出《霹靂嬌鋒》、《國際市場》、《拳力遊戲》等片，並以《政客誠實中》榮獲青龍獎影后肯定的「喜劇女王」羅美蘭，也將展現無愧於影后級的喜感演出。而在《愛上變身情人》、《代號：鐵鉻行動》、《神之一手》等片證明自己紮實演技內功的李凡秀，則飾演覬覦男主角父親幫派的副手，並同時宣告「元祖喜劇之王」的華麗回歸，而他滑頭滑腦又讓人無法討厭的搞笑演技，也將為本片增添活力，為觀眾再度帶來歡笑。不僅如此，本片還集結李璟榮、李準赫、吳代煥、印喬鎮、金元海、李中玉、黃在烈等個性十足的國寶級搶鏡者共同演出，提高觀眾們的期待！<br />
# <br />
# 本片在南韓上映之後，也獲得媒體與觀眾的高度支持，更一舉榮登「本土新片票房冠軍」。許多媒體紛紛給予好評，《首爾經濟》：「喜劇復仇者聯盟聚在一起了！」《日刊體育》：「喜劇之王與女王帶來的歡笑、感動、趣味盛宴！」《imbc》：「意想不到的感動，與超越預期的笑容！」《OSEN》：「搭載友情、矛盾、和解與成長的精采之作！」觀眾觀賞後也紛紛大讚：「又搞笑又溫暖！」「原本以為只是喜劇，沒想到最後竟受到感動！」「好久沒看到如此搞笑又感動的電影了！」「看完電影出來的時候，想起了爸爸！」讓本片無疑是適合闔家觀賞的溫馨爆笑強片。
#                 </span>
#               </div>
#
#
#             </div>
#             <div class="release_btn color_btnbox">
#               <a href="https://movies.yahoo.com.tw/movieinfo_main/%E7%AC%91%E5%AD%90%E7%95%B6%E8%80%81%E5%A4%A7-hometown-14171" class="btn_s_introduction"
#                  class="gabtn" data-ga="['上映中','上映中_上映中第1頁','笑子當老大']">
#                                      <span>電影資訊</span>
#                               </a>
#                                             <a href="https://movies.yahoo.com.tw/video/%E7%AC%91%E5%AD%90%E7%95%B6%E8%80%81%E5%A4%A7-%E8%A7%92%E8%89%B2%E7%89%88%E9%A0%90%E5%91%8A-084505580.html?movie_id=14171"
#                    class="btn_s_vedio gabtn" data-ga="['上映中','上映中_上映中第1頁','笑子當老大']">
#                   預告片
#                 </a>
#                                             <a href="https://movies.yahoo.com.tw/movieinfo_photos.html/id=14171" class="btn_s_foto">劇照</a>
#                                                               <a href="https://movies.yahoo.com.tw/movietime_result.html/id=14171"
#                     class="btn_s_time gabtn" data-ga="['上映中','上映中_上映中第1頁','笑子當老大']">
#                     時刻表
#                   </a>
#                                           </div>
#           </div>
#         </li>
#           </ul>
#   </div>
#   <div class="page_numbox">
#         <ul>
#
#         <li class="num_ar">&lsaquo;</li>
#                     <li class="prevtxt disabled"><span>上一頁</span></li>
#
#
#
#
#
#                                                                         <li class="active"><span>1</span></li>
#                                                                                 <li><a href="http://movies.yahoo.com.tw/movie_intheaters.html?page=2">2</a></li>
#                                                                                 <li><a href="http://movies.yahoo.com.tw/movie_intheaters.html?page=3">3</a></li>
#                                                                                 <li><a href="http://movies.yahoo.com.tw/movie_intheaters.html?page=4">4</a></li>
#                                                                                 <li><a href="http://movies.yahoo.com.tw/movie_intheaters.html?page=5">5</a></li>
#                                                                                 <li><a href="http://movies.yahoo.com.tw/movie_intheaters.html?page=6">6</a></li>
#                                                                                 <li><a href="http://movies.yahoo.com.tw/movie_intheaters.html?page=7">7</a></li>
#
#
#                     <li class="nexttxt"><a href="http://movies.yahoo.com.tw/movie_intheaters.html?page=2" rel="next">下一頁</a></li>
#                     <li class="num_ar">&rsaquo;</li>
#         </ul>
#     </div>
#
#           </div>
#         </div>
#       </div>
#     </main>
#     <footer id="footer" class="clearfix" style="display: block;">
#       <div id="loadbox">
#   <a class="gabtn" href="https://tw.help.yahoo.com/kb/helpcentral" target="_blank"
#      data-ga="['其他連結','其他連結_服務中心','頁尾_其他連結']">服務中心</a> | <a class="gabtn"
#                                                             href="https://policies.yahoo.com/tw/zh-hant/yahoo/privacy/index.htm"
#                                                             target="_blank"
#                                                             data-ga="['其他連結','其他連結_隱私權','頁尾_其他連結']">隱私權(更新)</a> | <a
#     class="gabtn" href="https://yahoo.uservoice.com/forums/600523" target="_blank"
#     data-ga="['其他連結','其他連結_建議','頁尾_其他連結']">建議</a> | <a class="gabtn"
#                                                        href="https://policies.yahoo.com/tw/zh-hant/yahoo/privacy/adinfo/"
#                                                        target="_blank" data-ga="['其他連結','其他連結_關於我們的廣告','頁尾_其他連結']">關於我們的廣告</a>
#   | <a class="gabtn" href="https://info.yahoo.com/legal/tw/yahoo/utos/zh-hant-tw/" target="_blank"
#        data-ga="['其他連結','其他連結_服務條款','頁尾_其他連結']">服務條款(更新)</a>
#   | <a href="" target="_blank">
#
#           </a>
#   由Yahoo奇摩電影戲劇 提供
# </div>    </footer>
#   </div>
#
# <!-- Javascript -->
# <script>
#     window.fbAsyncInit = function() {
#         FB.init({
#             appId            : 501887343352051,
#             autoLogAppEvents : true,
#             xfbml            : true,
#             version          : 'v14.0'
#         });
#         FB.AppEvents.logPageView();
#         // fb iframe 如果出現 error popup 的話會觸發focus，導致頁面被scroll至iframe的位置
#         // 目前先以外面的div加position:fixed，等fb iframe畫面render完成後，延遲2s
#         // (popup需要等iframe內的js載完才會出現)再移除position:fixed
#         FB.Event.subscribe('xfbml.render', function (response) {
#             setTimeout(()=> {
#                 $('.fb-page').removeClass('fb-position-fixed');
#             }, 2000);
#         });
#     };
#
#     function fb(d, s, id){
#         var js, fjs = d.getElementsByTagName(s)[0];
#         if (d.getElementById(id)) {return;}
#         js = d.createElement(s); js.id = id;
#         js.src = "//connect.facebook.net/en_US/sdk.js";
#         js.async = false;
#         js.defer = true;
#         fjs.parentNode.insertBefore(js, fjs);
#     };
#
#     setTimeout(() => {
#         fb(document, 'script', 'facebook-jssdk');
#     }, 5000);
#
#     function fbShareSend() {
#         var shareSendAll = document.querySelectorAll('.fb_share_send');
#         for(var i = 0; i < shareSendAll.length; i++) {
#             shareSendAll[i].onclick = function() {
#                 FB.ui({
#                     method: 'share_open_graph',
#                     action_type: 'og.likes',
#                     action_properties: JSON.stringify({
#                         object: this.getAttribute('data-href') ? this.getAttribute('data-href') : 'https://movies.yahoo.com.tw/movie_intheaters.html',
#                     })
#                 }, function(response){});
#             }
#         }
#     }
#
#     fbShareSend();
# </script>
#
# <!-- Native Ad -->
# <script type="text/javascript">
#   const nativeAdAll = "bdd2eb9c-51e8-404a-921c-ae7090fc5fda";
#   const nativeAdOption = "1160ac17-bf89-41d0-bf46-ede81bd550b9";
#
#   window.native = window.native || [];
#   window.native.push(nativeAdAll);
#   if(nativeAdOption.length) {
#     window.native.push(nativeAdOption);
#   }
#   window.apiKey = "QS4CB5BPWQKCYKVVSR89";
#
#   function nativeAdsSetup(d) {
#       var script = d.createElement("script");
#       script.async = true;
#       script.src = "https://s.yimg.com/dy/ads/native.dev.js";
#       d.body.appendChild(script);
#   };
#   setTimeout(()=> {
#     nativeAdsSetup(document)
#   }, [3000])
# </script>
#
# <script type="text/javascript" src="/build/js/vendor-jquery.js?id=7e26506326a182c4175e54acda7ef15e&amp;r=1667295665"></script>
# <script type="text/javascript" async src="/build/js/library.js?id=14b95e4146a6c6198c43e53c4aaef06a&amp;r=1667295665"></script>
# <script type="text/javascript" async src="/build/js/global.js?id=a9a1a05ef2946d693bc57bd11a4312ed&amp;r=1667295665"></script>
# <script type="text/javascript" async src="/build/js/main-layout.js?id=692340a3411d575876b70ca4baa5773e&amp;r=1667295665"></script>
# <script type="text/javascript" async src="/build/js/app-v2.js?id=d11e69363263741233106fca7eb7723f&amp;r=1667295665"></script>
#
# <noscript><img src="https://sb.scorecardresearch.com/p?c1=2&c2=7241469&c7=https%3A%2F%2Fmovies.yahoo.com.tw%2Fmovie_intheaters.html&c5=794026717&cv=2.0&cj=1" width="1" height="1" alt=""/></noscript>
# <script>
#
#
#
#   </script>
#
#
# </body>
#
# </html>

# %%
import bs4
root = bs4.BeautifulSoup(data, "html.parser")
# print(root.title.string) #上映中 - Yahoo奇摩電影戲劇

# %%
#尋找 ul標籤的 class_="release_list"
release_list = root.find_all("div", class_="release_movie_name") 
print (release_list)
# Out:
# [<div class="release_movie_name">
# <a class="gabtn" data-ga="['上映中','上映中_上映中第1頁','哥兒們']" href="https://movies.yahoo.com.tw/movieinfo_main/%E5%93%A5%E5%85%92%E5%80%91-bros-13337">
#                   哥兒們</a>
# <div class="en">
# <a class="gabtn" data-ga="['上映中','上映中_上映中第1頁','哥兒們']" href="https://movies.yahoo.com.tw/movieinfo_main/%E5%93%A5%E5%85%92%E5%80%91-bros-13337">
#                     Bros</a>
# </div>
# <dl class="levelbox">
# <dt>
# <div class="level_name">期待度</div>
# <div class="leveltext">
# <span>71%</span>
#                     網友想看
#                   </div>
# </dt>
# <dd>
# <div class="level_name">滿意度</div>
# <div class="leveltext">
# <span class="count" data-num="4.3" data-run="0">0</span>
#                       綜合評分
#                     </div>
# </dd>
# </dl>
# </div>, <div class="release_movie_name">
# <a class="gabtn" data-ga="['上映中','上映中_上映中第1頁','罪後真相']" href="https://movies.yahoo.com.tw/movieinfo_main/%E7%BD%AA%E5%BE%8C%E7%9C%9F%E7%9B%B8-the-post-truth-world-13836">
#                   罪後真相</a>
# <div class="en">
# <a class="gabtn" data-ga="['上映中','上映中_上映中第1頁','罪後真相']" href="https://movies.yahoo.com.tw/movieinfo_main/%E7%BD%AA%E5%BE%8C%E7%9C%9F%E7%9B%B8-the-post-truth-world-13836">
#                     The Post-Truth World</a>
# </div>
# <dl class="levelbox">
# <dt>
# <div class="level_name">期待度</div>
# <div class="leveltext">
# <span>86%</span>
#                     網友想看
#                   </div>
# </dt>
# <dd>
# <div class="level_name">滿意度</div>
# <div class="leveltext">
# <span class="count" data-num="4.4" data-run="0">0</span>
#                       綜合評分
#                     </div>
# </dd>
# </dl>
# </div>, <div class="release_movie_name">
# <a class="gabtn" data-ga="['上映中','上映中_上映中第1頁','調職令是警察樂隊！']" href="https://movies.yahoo.com.tw/movieinfo_main/%E8%AA%BF%E8%81%B7%E4%BB%A4%E6%98%AF%E8%AD%A6%E5%AF%9F%E6%A8%82%E9%9A%8A-offbeat-cops-13881">
#                   調職令是警察樂隊！</a>
# <div class="en">
# <a class="gabtn" data-ga="['上映中','上映中_上映中第1頁','調職令是警察樂隊！']" href="https://movies.yahoo.com.tw/movieinfo_main/%E8%AA%BF%E8%81%B7%E4%BB%A4%E6%98%AF%E8%AD%A6%E5%AF%9F%E6%A8%82%E9%9A%8A-offbeat-cops-13881">
#                     Offbeat Cops</a>
# </div>
# <dl class="levelbox">
# <dt>
# <div class="level_name">期待度</div>
# <div class="leveltext">
# <span>90%</span>
#                     網友想看
#                   </div>
# </dt>
# <dd>
# <div class="level_name">滿意度</div>
# <div class="leveltext">
# <span class="count" data-num="3.6" data-run="0">0</span>
#                       綜合評分
#                     </div>
# </dd>
# </dl>
# </div>, <div class="release_movie_name">
# <a class="gabtn" data-ga="['上映中','上映中_上映中第1頁','大俠胡金銓 第二部曲－斷腸人在天涯']" href="https://movies.yahoo.com.tw/movieinfo_main/%E5%A4%A7%E4%BF%A0%E8%83%A1%E9%87%91%E9%8A%93-%E7%AC%AC%E4%BA%8C%E9%83%A8%E6%9B%B2-%E6%96%B7%E8%85%B8%E4%BA%BA%E5%9C%A8%E5%A4%A9%E6%B6%AF-the-king-of-wuxia-part-2-the-heartbroken-man-on-the-horizon-13966">
#                   大俠胡金銓 第二部曲－斷腸人在天涯</a>
# <div class="en">
# <a class="gabtn" data-ga="['上映中','上映中_上映中第1頁','大俠胡金銓 第二部曲－斷腸人在天涯']" href="https://movies.yahoo.com.tw/movieinfo_main/%E5%A4%A7%E4%BF%A0%E8%83%A1%E9%87%91%E9%8A%93-%E7%AC%AC%E4%BA%8C%E9%83%A8%E6%9B%B2-%E6%96%B7%E8%85%B8%E4%BA%BA%E5%9C%A8%E5%A4%A9%E6%B6%AF-the-king-of-wuxia-part-2-the-heartbroken-man-on-the-horizon-13966">
#                     The King of Wuxia Part 2: The Heartbroken Man on the Horizon</a>
# </div>
# <dl class="levelbox">
# <dt>
# <div class="level_name">期待度</div>
# <div class="leveltext">
# <span>50%</span>
#                     網友想看
#                   </div>
# </dt>
# </dl>
# </div>, <div class="release_movie_name">
# <a class="gabtn" data-ga="['上映中','上映中_上映中第1頁','流麻溝十五號']" href="https://movies.yahoo.com.tw/movieinfo_main/%E6%B5%81%E9%BA%BB%E6%BA%9D%E5%8D%81%E4%BA%94%E8%99%9F-untold-herstory-14078">
#                   流麻溝十五號</a>
# <div class="en">
# <a class="gabtn" data-ga="['上映中','上映中_上映中第1頁','流麻溝十五號']" href="https://movies.yahoo.com.tw/movieinfo_main/%E6%B5%81%E9%BA%BB%E6%BA%9D%E5%8D%81%E4%BA%94%E8%99%9F-untold-herstory-14078">
#                     Untold Herstory</a>
# </div>
# <dl class="levelbox">
# <dt>
# <div class="level_name">期待度</div>
# <div class="leveltext">
# <span>83%</span>
#                     網友想看
#                   </div>
# </dt>
# <dd>
# <div class="level_name">滿意度</div>
# <div class="leveltext">
# <span class="count" data-num="4.2" data-run="0">0</span>
#                       綜合評分
#                     </div>
# </dd>
# </dl>
# </div>, <div class="release_movie_name">
# <a class="gabtn" data-ga="['上映中','上映中_上映中第1頁','鬼禱']" href="https://movies.yahoo.com.tw/movieinfo_main/%E9%AC%BC%E7%A6%B1-prey-for-the-devil-14119">
#                   鬼禱</a>
# <div class="en">
# <a class="gabtn" data-ga="['上映中','上映中_上映中第1頁','鬼禱']" href="https://movies.yahoo.com.tw/movieinfo_main/%E9%AC%BC%E7%A6%B1-prey-for-the-devil-14119">
#                     Prey for the Devil</a>
# </div>
# <dl class="levelbox">
# <dt>
# <div class="level_name">期待度</div>
# <div class="leveltext">
# <span>100%</span>
#                     網友想看
#                   </div>
# </dt>
# <dd>
# <div class="level_name">滿意度</div>
# <div class="leveltext">
# <span class="count" data-num="4.2" data-run="0">0</span>
#                       綜合評分
#                     </div>
# </dd>
# </dl>
# </div>, <div class="release_movie_name">
# <a class="gabtn" data-ga="['上映中','上映中_上映中第1頁','流浪之月']" href="https://movies.yahoo.com.tw/movieinfo_main/%E6%B5%81%E6%B5%AA%E4%B9%8B%E6%9C%88-wandering-14120">
#                   流浪之月</a>
# <div class="en">
# <a class="gabtn" data-ga="['上映中','上映中_上映中第1頁','流浪之月']" href="https://movies.yahoo.com.tw/movieinfo_main/%E6%B5%81%E6%B5%AA%E4%B9%8B%E6%9C%88-wandering-14120">
#                     Wandering</a>
# </div>
# <dl class="levelbox">
# <dt>
# <div class="level_name">期待度</div>
# <div class="leveltext">
# <span>100%</span>
#                     網友想看
#                   </div>
# </dt>
# <dd>
# <div class="level_name">滿意度</div>
# <div class="leveltext">
# <span class="count" data-num="4.6" data-run="0">0</span>
#                       綜合評分
#                     </div>
# </dd>
# </dl>
# </div>, <div class="release_movie_name">
# <a class="gabtn" data-ga="['上映中','上映中_上映中第1頁','詭孩']" href="https://movies.yahoo.com.tw/movieinfo_main/%E8%A9%AD%E5%AD%A9-the-innocents-14143">
#                   詭孩</a>
# <div class="en">
# <a class="gabtn" data-ga="['上映中','上映中_上映中第1頁','詭孩']" href="https://movies.yahoo.com.tw/movieinfo_main/%E8%A9%AD%E5%AD%A9-the-innocents-14143">
#                     The Innocents</a>
# </div>
# <dl class="levelbox">
# <dt>
# <div class="level_name">期待度</div>
# <div class="leveltext">
# <span>100%</span>
#                     網友想看
#                   </div>
# </dt>
# </dl>
# </div>, <div class="release_movie_name">
# <a class="gabtn" data-ga="['上映中','上映中_上映中第1頁','逃出風暴']" href="https://movies.yahoo.com.tw/movieinfo_main/%E9%80%83%E5%87%BA%E9%A2%A8%E6%9A%B4-and-tomorrow-we-will-be-dead-14155">
#                   逃出風暴</a>
# <div class="en">
# <a class="gabtn" data-ga="['上映中','上映中_上映中第1頁','逃出風暴']" href="https://movies.yahoo.com.tw/movieinfo_main/%E9%80%83%E5%87%BA%E9%A2%A8%E6%9A%B4-and-tomorrow-we-will-be-dead-14155">
#                     And Tomorrow We Will Be Dead</a>
# </div>
# <dl class="levelbox">
# <dt>
# <div class="level_name">期待度</div>
# <div class="leveltext">
# <span>100%</span>
#                     網友想看
#                   </div>
# </dt>
# </dl>
# </div>, <div class="release_movie_name">
# <a class="gabtn" data-ga="['上映中','上映中_上映中第1頁','笑子當老大']" href="https://movies.yahoo.com.tw/movieinfo_main/%E7%AC%91%E5%AD%90%E7%95%B6%E8%80%81%E5%A4%A7-hometown-14171">
#                   笑子當老大</a>
# <div class="en">
# <a class="gabtn" data-ga="['上映中','上映中_上映中第1頁','笑子當老大']" href="https://movies.yahoo.com.tw/movieinfo_main/%E7%AC%91%E5%AD%90%E7%95%B6%E8%80%81%E5%A4%A7-hometown-14171">
#                     Hometown</a>
# </div>
# <dl class="levelbox">
# <dt>
# <div class="level_name">期待度</div>
# <div class="leveltext">
# <span>98%</span>
#                     網友想看
#                   </div>
# </dt>
# <dd>
# <div class="level_name">滿意度</div>
# <div class="leveltext">
# <span class="count" data-num="2.7" data-run="0">0</span>
#                       綜合評分
#                     </div>
# </dd>
# </dl>
# </div>]
