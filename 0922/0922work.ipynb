# %%
import pandas as pd

# read csv file
hsinchu = pd.read_csv("hsinchu.csv", encoding="Big5")
newhsinchu = pd.read_csv("repair.csv", encoding="Big5")

# %%
newhsinchu
# Out:
#      屆別   姓名  職稱 性別   區別   里別            通訊地址        市內電話          行動電話
# 0    21  徐兆生  里長  男   東區  科園里         科學園路68號  03-5773761     932284536
# 1    21  張水源  里長  男   東區  仙宮里   寶山路452巷12弄20號           無  0910-157-478
# 2    21  吳慶杰  里長  男   東區  金山里     光復路1段163巷7號  03-5772652  0935-095-107
# 3    21  張文興  里長  男   東區  龍山里        龍山西路111號  03-5790159  0935-243-677
# 4    21  盧秋永  里長  男   東區  新莊里   新莊街266巷36弄31號  03-6662777  0935-948-035
# ..   ..  ...  .. ..  ...  ...             ...         ...           ...
# 99   21  陳文榮  里長  男  香山區  鹽水里       長興街262巷5號  03-5378671     928205692
# 100  21  林武鍾  里長  男  香山區  南港里        南港街54之2號           無     928241181
# 101  21  邱煥彬  里長  男  香山區  中隘里  新竹市中華路六段795巷2號  03-5374612     935769611
# 102  21  曾一德  里長  男  香山區  大湖里    五福路一段642巷28號           無     932286231
# 103  21  古秀芬  里長  女  香山區  茄苳里       五福路二段732號           無     958275287
#
# [104 rows x 9 columns]

# %%
hsinchu.tail()
# Out:
#      屆別   姓名  職稱 性別   區別   里別            通訊地址        市內電話          行動電話
# 117  21  林武鍾  里長  男  香山區  南港里        南港街54之2號           無     928241181
# 118  21  邱煥彬  里長  男  香山區  中隘里  新竹市中華路六段795巷2號  03-5374612     935769611
# 119  21  邱坤源  里長  男  香山區  南隘里         南湖路106號  03-5371036  0933-430-550
# 120  21  曾一德  里長  男  香山區  大湖里    五福路一段642巷28號           無     932286231
# 121  21  古秀芬  里長  女  香山區  茄苳里       五福路二段732號           無     958275287

# %%
alldt = list(hsinchu['姓名'])
print("里長總人數:", len(alldt), "；修改後里長總人數:", len(newhsinchu))
# Out:
# 里長總人數: 122 ；修改後里長總人數: 104

# %%
final_df = newhsinchu.drop_duplicates(subset=['姓名'])
final_df
# Out:
#      屆別   姓名  職稱 性別   區別   里別            通訊地址        市內電話          行動電話
# 0    21  徐兆生  里長  男   東區  科園里         科學園路68號  03-5773761     932284536
# 1    21  張水源  里長  男   東區  仙宮里   寶山路452巷12弄20號           無  0910-157-478
# 2    21  吳慶杰  里長  男   東區  金山里     光復路1段163巷7號  03-5772652  0935-095-107
# 3    21  張文興  里長  男   東區  龍山里        龍山西路111號  03-5790159  0935-243-677
# 4    21  盧秋永  里長  男   東區  新莊里   新莊街266巷36弄31號  03-6662777  0935-948-035
# ..   ..  ...  .. ..  ...  ...             ...         ...           ...
# 99   21  陳文榮  里長  男  香山區  鹽水里       長興街262巷5號  03-5378671     928205692
# 100  21  林武鍾  里長  男  香山區  南港里        南港街54之2號           無     928241181
# 101  21  邱煥彬  里長  男  香山區  中隘里  新竹市中華路六段795巷2號  03-5374612     935769611
# 102  21  曾一德  里長  男  香山區  大湖里    五福路一段642巷28號           無     932286231
# 103  21  古秀芬  里長  女  香山區  茄苳里       五福路二段732號           無     958275287
#
# [104 rows x 9 columns]

# %%
repair = list(newhsinchu['姓名'])

# %%
set(alldt).difference(set(repair))  #差集
# Out:
# {'?文泰',
#  '吳春生',
#  '徐水蓮',
#  '曾文澂',
#  '曾發',
#  '李文中',
#  '林錦全',
#  '楊金土',
#  '王?清',
#  '王斌展',
#  '莊榮文',
#  '趙強',
#  '邱坤源',
#  '邱漢奇',
#  '郭瑞誠',
#  '郭銘澤',
#  '韓榮春',
#  '駱純婕'}

# %%
set(alldt).intersection(set(repair)) #交集
# Out:
# {'何智昌',
#  '劉國棟',
#  '古秀芬',
#  '吳啟川',
#  '吳國亮',
#  '吳建銘',
#  '吳慶杰',
#  '吳月伶',
#  '吳烈如',
#  '吳瑞霖',
#  '呂賢輝',
#  '呂連村',
#  '廖佐華',
#  '廖成章',
#  '廖淑君',
#  '張慶榮',
#  '張文興',
#  '張水源',
#  '張浩燃',
#  '張進明',
#  '張金滄',
#  '張金潔',
#  '張雲錦',
#  '張麗芬',
#  '彭垂東',
#  '彭永泰',
#  '彭江',
#  '彭燦蓮',
#  '彭陳玉真',
#  '徐兆生',
#  '徐炳生',
#  '徐良芳',
#  '戴錦燦',
#  '曾一德',
#  '曾再霖',
#  '曾欽裕',
#  '曾翰揚',
#  '曾資強',
#  '朱志平',
#  '朱毅',
#  '朱鴻銘',
#  '李思民',
#  '李文桂',
#  '李臺生',
#  '杜榮輝',
#  '林俊縢',
#  '林再興',
#  '林志雅',
#  '林明志',
#  '林武鍾',
#  '林汶蓉',
#  '林耿輝',
#  '林輝雄',
#  '楊建標',
#  '楊松棋',
#  '楊賜濱',
#  '江玉寶',
#  '沈復環',
#  '沈朝旺',
#  '沈雄輝',
#  '洪添財',
#  '湯燕明',
#  '潘柏璋',
#  '王文福',
#  '王泰山',
#  '王立業',
#  '盧秋永',
#  '石添益',
#  '翁秀瓊',
#  '范姜財',
#  '莊子緩',
#  '莊淇松',
#  '莊火炎',
#  '莊金清',
#  '蔡坤龍',
#  '蔡文盛',
#  '蔡松根',
#  '蔡黃棟',
#  '蘇竹勝',
#  '謝金財',
#  '邱煥彬',
#  '郭天寶',
#  '郭文銘',
#  '郭朋鑫',
#  '鄔滬生',
#  '鄭榮一',
#  '鄭欽耀',
#  '鄭秀鳳',
#  '鄭錦章',
#  '鄭陳淑貞',
#  '陳嘉福',
#  '陳文榮',
#  '陳文賢',
#  '陳海鋒',
#  '韋宗洲',
#  '韋宗賢',
#  '黃丞廷',
#  '黃偉文',
#  '黃創港',
#  '黃千芳',
# ...

# %%
set(alldt).union(set(repair)) #聯集
# Out:
# {'?文泰',
#  '何智昌',
#  '劉國棟',
#  '古秀芬',
#  '吳啟川',
#  '吳國亮',
#  '吳建銘',
#  '吳慶杰',
#  '吳春生',
#  '吳月伶',
#  '吳烈如',
#  '吳瑞霖',
#  '呂賢輝',
#  '呂連村',
#  '廖佐華',
#  '廖成章',
#  '廖淑君',
#  '張慶榮',
#  '張文興',
#  '張水源',
#  '張浩燃',
#  '張進明',
#  '張金滄',
#  '張金潔',
#  '張雲錦',
#  '張麗芬',
#  '彭垂東',
#  '彭永泰',
#  '彭江',
#  '彭燦蓮',
#  '彭陳玉真',
#  '徐兆生',
#  '徐水蓮',
#  '徐炳生',
#  '徐良芳',
#  '戴錦燦',
#  '曾一德',
#  '曾再霖',
#  '曾文澂',
#  '曾欽裕',
#  '曾發',
#  '曾翰揚',
#  '曾資強',
#  '朱志平',
#  '朱毅',
#  '朱鴻銘',
#  '李思民',
#  '李文中',
#  '李文桂',
#  '李臺生',
#  '杜榮輝',
#  '林俊縢',
#  '林再興',
#  '林志雅',
#  '林明志',
#  '林武鍾',
#  '林汶蓉',
#  '林耿輝',
#  '林輝雄',
#  '林錦全',
#  '楊建標',
#  '楊松棋',
#  '楊賜濱',
#  '楊金土',
#  '江玉寶',
#  '沈復環',
#  '沈朝旺',
#  '沈雄輝',
#  '洪添財',
#  '湯燕明',
#  '潘柏璋',
#  '王?清',
#  '王文福',
#  '王斌展',
#  '王泰山',
#  '王立業',
#  '盧秋永',
#  '石添益',
#  '翁秀瓊',
#  '范姜財',
#  '莊子緩',
#  '莊榮文',
#  '莊淇松',
#  '莊火炎',
#  '莊金清',
#  '蔡坤龍',
#  '蔡文盛',
#  '蔡松根',
#  '蔡黃棟',
#  '蘇竹勝',
#  '謝金財',
#  '趙強',
#  '邱坤源',
#  '邱漢奇',
#  '邱煥彬',
#  '郭天寶',
#  '郭文銘',
#  '郭朋鑫',
#  '郭瑞誠',
#  '郭銘澤',
# ...

# %%
set(alldt).symmetric_difference(set(repair)) #對稱差集
# Out:
# {'?文泰',
#  '吳春生',
#  '徐水蓮',
#  '曾文澂',
#  '曾發',
#  '李文中',
#  '林錦全',
#  '楊金土',
#  '王?清',
#  '王斌展',
#  '莊榮文',
#  '趙強',
#  '邱坤源',
#  '邱漢奇',
#  '郭瑞誠',
#  '郭銘澤',
#  '韓榮春',
#  '駱純婕'}

# %%
# repair.csv是以 hsinchu.csv為原先檔刪除18位里長資料
